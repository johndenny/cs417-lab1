# %% [markdown]
# <a href="https://colab.research.google.com/github/johndenny/cs417-lab1/blob/main/CS417_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS 417 - Lab 1: Google Colab Introduction
# **Date:** [Today's Date]
# This notebook demonstrates basic Python concepts including:
# - Print statements
# - Variables
# - Basic arithmetic operations
# - String formatting

# %%
print("Welcome to Google Colab!")
print("Python makes programming fun!")
# Out:
# Welcome to Google Colab!
# Python makes programming fun!

# %%
# Working with variables
favorite_food = "pizza" # Replace with your favorite food
favorite_number = 7 # Replace with your favorite number
favorite_color = "blue" # Replace with your favorite color

print("My favorite food is:", favorite_food)
print("My favorite number is:", favorite_number)
print("My favorite color is:", favorite_color)
# Out:
# My favorite food is: pizza
# My favorite number is: 7
# My favorite color is: blue

# %%
first_name = "John"
last_name = "Denny"
full_name = first_name + " " + last_name
print("My full name is:", full_name)
# Out:
# My full name is: John Denny
